# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('data/iris.csv')
iris.iloc[:, 0:4].plot.box()
# Out:
# <AxesSubplot:>

# %%
iris.boxplot(by='Name')
# Out:
# array([[<AxesSubplot:title={'center':'PetalLength'}, xlabel='[Name]'>,
#         <AxesSubplot:title={'center':'PetalWidth'}, xlabel='[Name]'>],
#        [<AxesSubplot:title={'center':'SepalLength'}, xlabel='[Name]'>,
#         <AxesSubplot:title={'center':'SepalWidth'}, xlabel='[Name]'>]],
#       dtype=object)
